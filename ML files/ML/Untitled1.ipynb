# %%
# %cd drive/MyDrive/ML_praticals/Datasets/
# Out:
# /content/drive/MyDrive/ML_praticals/Datasets

# %%
# !ls
# Out:
#  AirQualityUCI.xlsx  'archive (9).zip'
#  AirQualityUCI.zip    archive.zip
# 'archive (10).zip'    city_day.csv
# 'archive (11).zip'    city_day.gsheet
# 'archive (12).zip'   'edited pollution index.xlsx'
# 'archive (13).zip'   'Latest Published Global Estimates (1751-2013).xlsx'
# 'archive (5).zip'     water_dataX.csv
# 'archive (6).zip'     water_dataX.gsheet

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("city_day.csv").dropna()

# %%
# Out:
# City            Chandigarh
# Date            2020-05-07
# PM2.5                13.54
# PM10                  50.6
# NO                    2.44
# NO2                   12.5
# NOx                   8.47
# NH3                  25.12
# CO                    0.59
# SO2                  12.11
# O3                    30.3
# Benzene               1.62
# Toluene               0.17
# Xylene                 0.9
# AQI                   56.0
# AQI_Bucket    Satisfactory
# Name: 7778, dtype: object
