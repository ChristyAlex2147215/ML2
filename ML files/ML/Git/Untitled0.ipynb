# %%
# %cd /content/drive/MyDrive/ML/Git
# Out:
# /content/drive/MyDrive/ML/Git

# %%
# !git clone https://github.com/codebasics/py.git
# Out:
# Cloning into 'py'...
# remote: Enumerating objects: 2889, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 2889 (delta 4), reused 9 (delta 1), pack-reused 2874
# Receiving objects: 100% (2889/2889), 196.65 MiB | 14.57 MiB/s, done.
# Resolving deltas: 100% (1115/1115), done.
# Checking out files: 100% (1388/1388), done.
