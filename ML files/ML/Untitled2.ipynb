# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ML/Datasets/
# Out:
# /content/drive/MyDrive/ML/Datasets

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("city_day.csv").dropna()
df
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
for i in df['Xylene']:
  if i<df.iloc[:,[14]].mean():
      df["X"]

# %%
df.iloc[:,[1,14]]

# %%
df
# Out:
#                 City  Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 2123       Amaravati   777  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2124       Amaravati   777  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 2125       Amaravati   777  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 2126       Amaravati   777  64.18  104.09  2.56  28.07  17.01  11.42  0.09
# 2127       Amaravati   777  72.47  114.84  5.23  23.20  16.59  12.25  0.16
# ...              ...   ...    ...     ...   ...    ...    ...    ...   ...
# 29525  Visakhapatnam   777   7.63   32.27  5.91  23.27  17.19  11.15  0.46
# 29526  Visakhapatnam   777  15.02   50.94  7.68  25.06  19.54  12.47  0.47
# 29527  Visakhapatnam   777  24.38   74.09  3.42  26.06  16.53  11.99  0.52
# 29528  Visakhapatnam   777  22.91   65.73  3.45  29.53  18.33  10.71  0.48
# 29529  Visakhapatnam   777  16.64   49.97  4.05  29.26  18.80  10.03  0.52
#
#          SO2      O3  Benzene  Toluene  Xylene  AQI    AQI_Bucket
# ...
