# %% [markdown]
# #1. Write python code using sklearn library to demonstrate KNN classification for
# minimum 5 different values of K for given dataset. Demonstrate if any
# preprocessing step could improve the performance of the classifier. The code
# should also include relevant plot image to visualize the obtained results. Provide
# conceptual interpretation of the results.

# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
df=pd.read_csv("/content/mushrooms - mushrooms.csv")

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e       NaN           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# for class atrribute

# %%
df["class"].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
df["class"]=df["class"].map({'p':0,'e':1})

# %% [markdown]
# for cap shape attribute

# %%
df["cap-shape"].unique()
# Out:
# array(['x', 'b', nan, 's', 'f', 'k', 'c'], dtype=object)

# %%
df["cap-shape"]=df["cap-shape"].map({'x':0, 'b':1, 's':2, 'f':3, 'k':4, 'c':5})

# %% [markdown]
# for cap surface attribute

# %%
df["cap-surface"].unique()
# Out:
# array(['s', 'y', 'f', 'g'], dtype=object)

# %%
df["cap-surface"]=df["cap-surface"].map({'s':0, 'y':1, 'f':2, 'g':3})

# %% [markdown]
# for cap color dataset

# %%
df["cap-color"].unique()
# Out:
# array(['n', 'y', 'w', 'g', 'e', 'p', 'b', 'u', 'c', 'r'], dtype=object)

# %%
df["cap-color"]=df["cap-color"].map({'n':0, 'y':1, 'w':2, 'g':3, 'e':4, 'p':5, 'b':6, 'u':7, 'c':8, 'r':9})

# %% [markdown]
# for bruises

# %%
df["bruises"].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %%
df["bruises"]=df["bruises"].map({'t':0, 'f':1})

# %% [markdown]
# for ordor

# %%
df["odor"].unique()
# Out:
# array(['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm'], dtype=object)

# %%
df["odor"]=df["odor"].map({'p':0, 'a':1, 'l':2, 'n':3, 'f':4, 'c':5, 'y':6, 's':7, 'm':8})

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor gill-attachment  \
# 0         0        0.0            0          0        0     0               f
# 1         1        0.0            0          1        0     1               f
# 2         1        1.0            0          2        0     2               f
# 3         0        0.0            1          2        0     0               f
# 4         1        NaN            0          3        1     3               f
# ...     ...        ...          ...        ...      ...   ...             ...
# 8119      1        4.0            0          0        1     3               a
# 8120      1        0.0            0          0        1     3               a
# 8121      1        3.0            0          0        1     3               a
# 8122      0        4.0            1          0        1     6               f
# 8123      1        0.0            0          0        1     3               a
#
# ...

# %%
df["cap-shape"].isnull().sum()
# Out:
# 1

# %%
#replacing all the null values with mean
df["cap-shape"] = df["cap-shape"].fillna(df["cap-shape"].mean())

# %%
df["cap-surface"].isnull().sum()
# Out:
# 0

# %%
df["cap-color"].isnull().sum()
# Out:
# 0

# %%
print(df["class"][0])
print(df["class"][1])
# Out:
# 0
# 1

# %%
dff=df[["class","cap-shape","cap-surface","cap-color","bruises","odor"]]

# %%
dff
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor
# 0         0   0.000000            0          0        0     0
# 1         1   0.000000            0          1        0     1
# 2         1   1.000000            0          2        0     2
# 3         0   0.000000            1          2        0     0
# 4         1   1.637819            0          3        1     3
# ...     ...        ...          ...        ...      ...   ...
# 8119      1   4.000000            0          0        1     3
# 8120      1   0.000000            0          0        1     3
# 8121      1   3.000000            0          0        1     3
# 8122      0   4.000000            1          0        1     6
# 8123      1   0.000000            0          0        1     3
#
# [8124 rows x 6 columns]

# %%
dff[dff["class"]==0].shape
# Out:
# (3916, 6)

# %%
dff[dff["class"]==1].shape
# Out:
# (4208, 6)

# %% [markdown]
# grouping the dataset accoding to class attribute

# %%
dffg=dff.groupby("class")

# %%
dffg.head()
# Out:
#     class  cap-shape  cap-surface  cap-color  bruises  odor
# 0       0   0.000000            0          0        0     0
# 1       1   0.000000            0          1        0     1
# 2       1   1.000000            0          2        0     2
# 3       0   0.000000            1          2        0     0
# 4       1   1.637819            0          3        1     3
# 5       1   0.000000            1          1        0     1
# 6       1   1.000000            0          2        0     1
# 8       0   0.000000            1          2        0     0
# 13      0   0.000000            1          2        0     0
# 17      0   0.000000            0          0        0     0

# %%
dff.sort_values(by=['class'], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
dff
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor
# 0         0        0.0            0          0        0     0
# 7024      0        0.0            0          0        1     6
# 1204      0        3.0            0          2        0     0
# 7023      0        4.0            0          4        1     6
# 7060      0        0.0            0          4        1     6
# ...     ...        ...          ...        ...      ...   ...
# 1823      1        3.0            2          0        0     3
# 1821      1        0.0            2          0        1     3
# 1820      1        3.0            0          0        1     3
# 1818      1        3.0            0          2        1     3
# 8123      1        0.0            0          0        1     3
#
# [8124 rows x 6 columns]

# %%
# for  i  in dff[3916:8124]["class"]:
#   print(i)

# %%
#splitting the dataset accoding to classs attributes
dff1=dff[:3916]
dff2=dff[3916:7832]

# %%
# df1

# %%
dff.head()
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor
# 0         0        0.0            0          0        0     0
# 5328      0        0.0            1          4        1     6
# 5327      0        3.0            2          3        1     4
# 5326      0        0.0            1          0        1     7
# 5324      0        0.0            1          0        1     4

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.xlabel('cap-shape')
plt.ylabel('cap-surface')
plt.scatter(dff1['cap-shape'], dff1['cap-surface'],color="green",marker='+')
plt.scatter(dff2['cap-shape'], dff2['cap-surface'],color="blue",marker='*')

# %%
plt.xlabel('bruises')
plt.ylabel('odor')
plt.scatter(dff1['bruises'], dff1['odor'],color="green",marker='+')
plt.scatter(dff2['bruises'], dff2['odor'],color="blue",marker='.')

# %%
dff
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor
# 0         0        0.0            0          0        0     0
# 5328      0        0.0            1          4        1     6
# 5327      0        3.0            2          3        1     4
# 5326      0        0.0            1          0        1     7
# 5324      0        0.0            1          0        1     4
# ...     ...        ...          ...        ...      ...   ...
# 2530      1        0.0            1          3        0     3
# 2529      1        3.0            2          0        0     3
# 2528      1        0.0            1          0        0     3
# 2526      1        0.0            2          3        0     3
# 8123      1        0.0            0          0        1     3
#
# [8124 rows x 6 columns]

# %% [markdown]
# #

# %%
from sklearn.model_selection import train_test_split

# %%
X = dff.drop(['class'], axis='columns')
y = df["class"]

# %%
X
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor
# 0           0.0            0          0        0     0
# 5328        0.0            1          4        1     6
# 5327        3.0            2          3        1     4
# 5326        0.0            1          0        1     7
# 5324        0.0            1          0        1     4
# ...         ...          ...        ...      ...   ...
# 2530        0.0            1          3        0     3
# 2529        3.0            2          0        0     3
# 2528        0.0            1          0        0     3
# 2526        0.0            2          3        0     3
# 8123        0.0            0          0        1     3
#
# [8124 rows x 5 columns]

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 8119    1
# 8120    1
# 8121    1
# 8122    0
# 8123    1
# Name: class, Length: 8124, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X[:700], y[:700], test_size=0.2, random_state=1)

# %%
len(X_train)
# Out:
# 560

# %%
len(X_test)
# Out:
# 140

# %% [markdown]
# #applying the KNN

# %% [markdown]
# for k=10

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
knn.score(X_test, y_test)
# Out:
# 0.8785714285714286

# %% [markdown]
# #for k=2

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=2)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn.score(X_test, y_test)
# Out:
# 0.8

# %% [markdown]
# for k=3

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.score(X_test, y_test)
# Out:
# 0.8785714285714286

# %% [markdown]
# for k=15

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=15)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
knn.score(X_test, y_test)
# Out:
# 0.5975384615384616

# %% [markdown]
# #adding the confusion matrix

# %%
from sklearn.metrics import confusion_matrix
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[679, 126],
#        [202, 618]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(7,5))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(42.0, 0.5, 'Truth')

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60       805
#            1       0.61      0.61      0.61       820
#
#     accuracy                           0.61      1625
#    macro avg       0.61      0.61      0.61      1625
# weighted avg       0.61      0.61      0.61      1625

# %% [markdown]
# #description
# the data provided was a list  of categorisation of the mushroom
# total
