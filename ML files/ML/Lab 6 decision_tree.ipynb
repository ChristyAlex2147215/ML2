# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/ML/Preprocesses_city_day - Preprocesses_city_day.csv")

# %%
df
# Out:
#           ID           City        Date   PM2.5        PM10     NO    NO2  \
# 0         28      Ahmedabad  2015-01-29   83.13  118.127103   6.93  28.71
# 1         29      Ahmedabad  2015-01-30   79.84  118.127103  13.85  28.68
# 2         30      Ahmedabad  2015-01-31   94.52  118.127103  24.39  32.66
# 3         31      Ahmedabad  2015-02-01  135.99  118.127103  43.48  42.08
# 4         32      Ahmedabad  2015-02-02  178.33  118.127103  54.56  35.31
# ...      ...            ...         ...     ...         ...    ...    ...
# 24845  29526  Visakhapatnam  2020-06-27   15.02   50.940000   7.68  25.06
# 24846  29527  Visakhapatnam  2020-06-28   24.38   74.090000   3.42  26.06
# 24847  29528  Visakhapatnam  2020-06-29   22.91   65.730000   3.45  29.53
# 24848  29529  Visakhapatnam  2020-06-30   16.64   49.970000   4.05  29.26
# 24849  29530  Visakhapatnam  2020-07-01   15.00   66.000000   0.40  26.85
#
#          NOx        NH3     CO    SO2      O3  Benzene    Toluene     Xylene  \
# 0      33.72  23.483476   6.93  49.52   59.76  0.02000   0.000000   3.140000
# 1      41.08  23.483476  13.85  48.49   97.07  0.04000   0.000000   4.810000
# 2      52.61  23.483476  24.39  67.39  111.33  0.24000   0.010000   7.670000
# 3      84.57  23.483476  43.48  75.23  102.70  0.40000   0.040000  25.870000
# 4      72.80  23.483476  54.56  55.04  107.38  0.46000   0.060000  35.610000
# ...      ...        ...    ...    ...     ...      ...        ...        ...
# 24845  19.54  12.470000   0.47   8.55   23.30  2.24000  12.070000   0.730000
# 24846  16.53  11.990000   0.52  12.72   30.14  0.74000   2.210000   0.380000
# 24847  18.33  10.710000   0.48   8.42   30.96  0.01000   0.010000   0.000000
# 24848  18.80  10.030000   0.52   9.84   28.30  0.00000   0.000000   0.000000
# 24849  14.05   5.200000   0.59   2.10   17.05  3.28084   8.700972   3.070128
#
#        AQI    AQI_Bucket
# 0      209          Poor
# 1      328     Very Poor
# 2      514        Severe
# 3      782        Severe
# 4      914        Severe
# ...    ...           ...
# 24845   41          Good
# 24846   70  Satisfactory
# 24847   68  Satisfactory
# 24848   54  Satisfactory
# 24849   50          Good
#
# [24850 rows x 17 columns]

# %%
from pandas.core.strings.accessor import str_extractall
def numerizecolumns(name,df):
  dict={}
  listt=list(df[str(name)].unique())
  print(listt)
  for i in listt:
    # print("i values is :"+str(i))
    for j in range(0,len(listt)):
      # print("j values is "+str(j))
      if j not in dict.values():
        # print("j value adding is"+str(j))
        dict.update({str(i):j})
  df[str(name)]=df[str(name)].map(dict)
  print(dict)



numerizecolumns("AQI_Bucket",df)
# Out:
# ['Poor', 'Very Poor', 'Severe', 'Moderate', 'Satisfactory', 'Good']
# {'Poor': 5, 'Very Poor': 4, 'Severe': 3, 'Moderate': 2, 'Satisfactory': 1, 'Good': 0}

# %%
from pandas.core.strings.accessor import str_extractall
def numerizecolumns(name,df):
  dict={}
  listt=list(df[str(name)].unique())
  print(listt)
  for i in listt:
    # print("i values is :"+str(i))
    for j in range(0,len(listt)):
      # print("j values is "+str(j))
      if j not in dict.values():
        # print("j value adding is"+str(j))
        dict.update({str(i):j})
  df[str(name)]=df[str(name)].map(dict)
  print(dict)



numerizecolumns("City",df)
# Out:
# ['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru', 'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore', 'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad', 'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai', 'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram', 'Visakhapatnam']
# {'Ahmedabad': 25, 'Aizawl': 24, 'Amaravati': 23, 'Amritsar': 22, 'Bengaluru': 21, 'Bhopal': 20, 'Brajrajnagar': 19, 'Chandigarh': 18, 'Chennai': 17, 'Coimbatore': 16, 'Delhi': 15, 'Ernakulam': 14, 'Gurugram': 13, 'Guwahati': 12, 'Hyderabad': 11, 'Jaipur': 10, 'Jorapokhar': 9, 'Kochi': 8, 'Kolkata': 7, 'Lucknow': 6, 'Mumbai': 5, 'Patna': 4, 'Shillong': 3, 'Talcher': 2, 'Thiruvananthapuram': 1, 'Visakhapatnam': 0}

# %%
df
# Out:
#           ID  City        Date   PM2.5        PM10     NO    NO2    NOx  \
# 0         28    25  2015-01-29   83.13  118.127103   6.93  28.71  33.72
# 1         29    25  2015-01-30   79.84  118.127103  13.85  28.68  41.08
# 2         30    25  2015-01-31   94.52  118.127103  24.39  32.66  52.61
# 3         31    25  2015-02-01  135.99  118.127103  43.48  42.08  84.57
# 4         32    25  2015-02-02  178.33  118.127103  54.56  35.31  72.80
# ...      ...   ...         ...     ...         ...    ...    ...    ...
# 24845  29526     0  2020-06-27   15.02   50.940000   7.68  25.06  19.54
# 24846  29527     0  2020-06-28   24.38   74.090000   3.42  26.06  16.53
# 24847  29528     0  2020-06-29   22.91   65.730000   3.45  29.53  18.33
# 24848  29529     0  2020-06-30   16.64   49.970000   4.05  29.26  18.80
# 24849  29530     0  2020-07-01   15.00   66.000000   0.40  26.85  14.05
#
#              NH3     CO    SO2      O3  Benzene    Toluene     Xylene  AQI  \
# 0      23.483476   6.93  49.52   59.76  0.02000   0.000000   3.140000  209
# 1      23.483476  13.85  48.49   97.07  0.04000   0.000000   4.810000  328
# 2      23.483476  24.39  67.39  111.33  0.24000   0.010000   7.670000  514
# 3      23.483476  43.48  75.23  102.70  0.40000   0.040000  25.870000  782
# 4      23.483476  54.56  55.04  107.38  0.46000   0.060000  35.610000  914
# ...          ...    ...    ...     ...      ...        ...        ...  ...
# 24845  12.470000   0.47   8.55   23.30  2.24000  12.070000   0.730000   41
# 24846  11.990000   0.52  12.72   30.14  0.74000   2.210000   0.380000   70
# 24847  10.710000   0.48   8.42   30.96  0.01000   0.010000   0.000000   68
# 24848  10.030000   0.52   9.84   28.30  0.00000   0.000000   0.000000   54
# 24849   5.200000   0.59   2.10   17.05  3.28084   8.700972   3.070128   50
#
#        AQI_Bucket
# 0               5
# 1               4
# 2               3
# 3               3
# 4               3
# ...           ...
# 24845           0
# 24846           1
# 24847           1
# 24848           1
# 24849           0
#
# [24850 rows x 17 columns]

# %% [markdown]
# #to change the string data to number

# %%
def numerifyDate(stri):
  string=stri
  st=string.split("-")[2]+string.split("-")[1]+string.split("-")[0]
  return int(st)

for i in range(0,df["Date"].size):
  df["Date"][i]=numerifyDate(df["Date"][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df
# Out:
#           ID  City      Date   PM2.5        PM10     NO    NO2    NOx  \
# 0         28    25  29012015   83.13  118.127103   6.93  28.71  33.72
# 1         29    25  30012015   79.84  118.127103  13.85  28.68  41.08
# 2         30    25  31012015   94.52  118.127103  24.39  32.66  52.61
# 3         31    25   1022015  135.99  118.127103  43.48  42.08  84.57
# 4         32    25   2022015  178.33  118.127103  54.56  35.31  72.80
# ...      ...   ...       ...     ...         ...    ...    ...    ...
# 24845  29526     0  27062020   15.02   50.940000   7.68  25.06  19.54
# 24846  29527     0  28062020   24.38   74.090000   3.42  26.06  16.53
# 24847  29528     0  29062020   22.91   65.730000   3.45  29.53  18.33
# 24848  29529     0  30062020   16.64   49.970000   4.05  29.26  18.80
# 24849  29530     0   1072020   15.00   66.000000   0.40  26.85  14.05
#
#              NH3     CO    SO2      O3  Benzene    Toluene     Xylene  AQI  \
# 0      23.483476   6.93  49.52   59.76  0.02000   0.000000   3.140000  209
# 1      23.483476  13.85  48.49   97.07  0.04000   0.000000   4.810000  328
# 2      23.483476  24.39  67.39  111.33  0.24000   0.010000   7.670000  514
# 3      23.483476  43.48  75.23  102.70  0.40000   0.040000  25.870000  782
# 4      23.483476  54.56  55.04  107.38  0.46000   0.060000  35.610000  914
# ...          ...    ...    ...     ...      ...        ...        ...  ...
# 24845  12.470000   0.47   8.55   23.30  2.24000  12.070000   0.730000   41
# 24846  11.990000   0.52  12.72   30.14  0.74000   2.210000   0.380000   70
# 24847  10.710000   0.48   8.42   30.96  0.01000   0.010000   0.000000   68
# 24848  10.030000   0.52   9.84   28.30  0.00000   0.000000   0.000000   54
# 24849   5.200000   0.59   2.10   17.05  3.28084   8.700972   3.070128   50
#
#        AQI_Bucket
# 0               5
# 1               4
# 2               3
# 3               3
# 4               3
# ...           ...
# 24845           0
# 24846           1
# 24847           1
# 24848           1
# 24849           0
#
# [24850 rows x 17 columns]

# %%
df["Date"].size
# Out:
# 24850

# %%
df.columns.unique()
# Out:
# Index(['ID', 'City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df2=df[['ID', 'City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
       'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']]

# %%
df2
# Out:
#           ID  City   PM2.5        PM10     NO    NO2    NOx        NH3     CO  \
# 0         28    25   83.13  118.127103   6.93  28.71  33.72  23.483476   6.93
# 1         29    25   79.84  118.127103  13.85  28.68  41.08  23.483476  13.85
# 2         30    25   94.52  118.127103  24.39  32.66  52.61  23.483476  24.39
# 3         31    25  135.99  118.127103  43.48  42.08  84.57  23.483476  43.48
# 4         32    25  178.33  118.127103  54.56  35.31  72.80  23.483476  54.56
# ...      ...   ...     ...         ...    ...    ...    ...        ...    ...
# 24845  29526     0   15.02   50.940000   7.68  25.06  19.54  12.470000   0.47
# 24846  29527     0   24.38   74.090000   3.42  26.06  16.53  11.990000   0.52
# 24847  29528     0   22.91   65.730000   3.45  29.53  18.33  10.710000   0.48
# 24848  29529     0   16.64   49.970000   4.05  29.26  18.80  10.030000   0.52
# 24849  29530     0   15.00   66.000000   0.40  26.85  14.05   5.200000   0.59
#
#          SO2      O3  Benzene    Toluene     Xylene  AQI  AQI_Bucket
# 0      49.52   59.76  0.02000   0.000000   3.140000  209           5
# 1      48.49   97.07  0.04000   0.000000   4.810000  328           4
# 2      67.39  111.33  0.24000   0.010000   7.670000  514           3
# 3      75.23  102.70  0.40000   0.040000  25.870000  782           3
# 4      55.04  107.38  0.46000   0.060000  35.610000  914           3
# ...      ...     ...      ...        ...        ...  ...         ...
# 24845   8.55   23.30  2.24000  12.070000   0.730000   41           0
# 24846  12.72   30.14  0.74000   2.210000   0.380000   70           1
# 24847   8.42   30.96  0.01000   0.010000   0.000000   68           1
# 24848   9.84   28.30  0.00000   0.000000   0.000000   54           1
# 24849   2.10   17.05  3.28084   8.700972   3.070128   50           0
#
# [24850 rows x 16 columns]

# %%
mean = df.loc[df['B'].eq(1), 'A'].mean()
print (mean)
54.0

mask = df['A'].lt(mean) & df['B'].eq(-1)
df.loc[mask, 'A'] = mean

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X = df[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene','AQI']]
y = df['AQI_Bucket']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
scaler = StandardScaler()

scaled_x_train = scaler.fit_transform(X_train)
scaled_x_test = scaler.transform(X_test)

scaled_x_train
# Out:
# array([[ 0.49540572,  1.85068973, -0.43921299, ..., -0.52728103,
#         -0.04888095,  0.45726014],
#        [ 0.269129  ,  0.42392679,  0.06669038, ..., -0.15112334,
#         -0.04888095,  0.10559155],
#        [-0.44417988, -0.56142804, -0.58652412, ..., -0.37352729,
#         -0.73556658, -0.66233782],
#        ...,
#        [-0.57006735, -0.0023585 , -0.593732  , ..., -0.50969297,
#         -0.04888095, -0.18866176],
#        [ 0.67148781, -0.0023585 , -0.12386806, ..., -0.47281476,
#         -0.04888095,  0.56491379],
#        [-0.57680274, -0.31884642, -0.6622069 , ..., -0.12162078,
#         -0.44656991,  0.15582992]])

# %%
log_model = LogisticRegression()

# Fit the model :
log_model.fit(scaled_x_train,y_train)
y_prop = log_model.predict_proba(scaled_x_test)
y_prop
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# array([[5.25806102e-21, 7.89676206e-11, 6.63541783e-02, 3.05295458e-08,
#         1.10063958e-02, 9.22639395e-01],
#        [7.85681558e-03, 9.55969595e-01, 3.61725837e-02, 9.47596810e-24,
#         1.89829080e-13, 1.00600182e-06],
#        [6.72909746e-21, 1.01347846e-10, 7.68978978e-02, 4.15499044e-08,
#         9.97077766e-03, 9.13131283e-01],
#        ...,
#        [1.43791509e-32, 4.17417752e-18, 1.25400666e-04, 1.86672538e-04,
#         5.22053301e-01, 4.77634625e-01],
#        [1.62806864e-02, 9.59406085e-01, 2.43126623e-02, 4.43595766e-24,
#         9.30504037e-14, 5.66030632e-07],
#        [1.96139487e-07, 2.15845332e-02, 9.76909735e-01, 9.51947804e-18,
#         7.20721731e-09, 1.50552864e-03]])

# %%
y_pred = log_model.predict(scaled_x_test)
y_pred
# Out:
# array([5, 1, 5, ..., 4, 1, 2])

# %% [markdown]
# #TREE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
dt = DecisionTreeClassifier(max_depth = 3)

dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
plt.figure(figsize=(27,14))
plot_tree(dt, feature_names = X.columns, class_names=['5','4','3','2','1','0'], filled=True);

# %% [markdown]
# #Linear Regression

# %%
df1=pd.read_csv('/content/drive/MyDrive/ML/Preprocesses_city_day - Preprocesses_city_day.csv')
df1
# Out:
#           ID           City        Date   PM2.5        PM10     NO    NO2  \
# 0         28      Ahmedabad  2015-01-29   83.13  118.127103   6.93  28.71
# 1         29      Ahmedabad  2015-01-30   79.84  118.127103  13.85  28.68
# 2         30      Ahmedabad  2015-01-31   94.52  118.127103  24.39  32.66
# 3         31      Ahmedabad  2015-02-01  135.99  118.127103  43.48  42.08
# 4         32      Ahmedabad  2015-02-02  178.33  118.127103  54.56  35.31
# ...      ...            ...         ...     ...         ...    ...    ...
# 24845  29526  Visakhapatnam  2020-06-27   15.02   50.940000   7.68  25.06
# 24846  29527  Visakhapatnam  2020-06-28   24.38   74.090000   3.42  26.06
# 24847  29528  Visakhapatnam  2020-06-29   22.91   65.730000   3.45  29.53
# 24848  29529  Visakhapatnam  2020-06-30   16.64   49.970000   4.05  29.26
# 24849  29530  Visakhapatnam  2020-07-01   15.00   66.000000   0.40  26.85
#
#          NOx        NH3     CO    SO2      O3  Benzene    Toluene     Xylene  \
# 0      33.72  23.483476   6.93  49.52   59.76  0.02000   0.000000   3.140000
# 1      41.08  23.483476  13.85  48.49   97.07  0.04000   0.000000   4.810000
# 2      52.61  23.483476  24.39  67.39  111.33  0.24000   0.010000   7.670000
# 3      84.57  23.483476  43.48  75.23  102.70  0.40000   0.040000  25.870000
# 4      72.80  23.483476  54.56  55.04  107.38  0.46000   0.060000  35.610000
# ...      ...        ...    ...    ...     ...      ...        ...        ...
# 24845  19.54  12.470000   0.47   8.55   23.30  2.24000  12.070000   0.730000
# 24846  16.53  11.990000   0.52  12.72   30.14  0.74000   2.210000   0.380000
# 24847  18.33  10.710000   0.48   8.42   30.96  0.01000   0.010000   0.000000
# 24848  18.80  10.030000   0.52   9.84   28.30  0.00000   0.000000   0.000000
# 24849  14.05   5.200000   0.59   2.10   17.05  3.28084   8.700972   3.070128
#
#        AQI    AQI_Bucket
# 0      209          Poor
# 1      328     Very Poor
# 2      514        Severe
# 3      782        Severe
# 4      914        Severe
# ...    ...           ...
# 24845   41          Good
# 24846   70  Satisfactory
# 24847   68  Satisfactory
# 24848   54  Satisfactory
# 24849   50          Good
#
# [24850 rows x 17 columns]

# %%
numerizecolumns("AQI_Bucket",df1)
numerizecolumns("City",df1)
# Out:
# ['Poor', 'Very Poor', 'Severe', 'Moderate', 'Satisfactory', 'Good']
# {'Poor': 5, 'Very Poor': 4, 'Severe': 3, 'Moderate': 2, 'Satisfactory': 1, 'Good': 0}
# ['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru', 'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore', 'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad', 'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai', 'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram', 'Visakhapatnam']
# {'Ahmedabad': 25, 'Aizawl': 24, 'Amaravati': 23, 'Amritsar': 22, 'Bengaluru': 21, 'Bhopal': 20, 'Brajrajnagar': 19, 'Chandigarh': 18, 'Chennai': 17, 'Coimbatore': 16, 'Delhi': 15, 'Ernakulam': 14, 'Gurugram': 13, 'Guwahati': 12, 'Hyderabad': 11, 'Jaipur': 10, 'Jorapokhar': 9, 'Kochi': 8, 'Kolkata': 7, 'Lucknow': 6, 'Mumbai': 5, 'Patna': 4, 'Shillong': 3, 'Talcher': 2, 'Thiruvananthapuram': 1, 'Visakhapatnam': 0}

# %%
from scipy import stats

# %%
df2=df1.head(100)
df2
# Out:
#      ID  City        Date   PM2.5        PM10     NO    NO2    NOx        NH3  \
# 0    28    25  2015-01-29   83.13  118.127103   6.93  28.71  33.72  23.483476
# 1    29    25  2015-01-30   79.84  118.127103  13.85  28.68  41.08  23.483476
# 2    30    25  2015-01-31   94.52  118.127103  24.39  32.66  52.61  23.483476
# 3    31    25  2015-02-01  135.99  118.127103  43.48  42.08  84.57  23.483476
# 4    32    25  2015-02-02  178.33  118.127103  54.56  35.31  72.80  23.483476
# ..  ...   ...         ...     ...         ...    ...    ...    ...        ...
# 95  134    25  2015-05-15  129.27  118.127103  14.28  28.33  41.92  23.483476
# 96  135    25  2015-05-16  129.58  118.127103  21.23  28.79  45.40  23.483476
# 97  136    25  2015-05-17  100.57  118.127103   7.56  18.79  24.33  23.483476
# 98  137    25  2015-05-18  130.34  118.127103   7.14  17.43  23.72  23.483476
# 99  138    25  2015-05-19   53.24  118.127103   8.05  15.86  23.34  23.483476
#
#        CO    SO2      O3  Benzene  Toluene  Xylene  AQI  AQI_Bucket
# 0    6.93  49.52   59.76     0.02     0.00    3.14  209           5
# 1   13.85  48.49   97.07     0.04     0.00    4.81  328           4
# 2   24.39  67.39  111.33     0.24     0.01    7.67  514           3
# 3   43.48  75.23  102.70     0.40     0.04   25.87  782           3
# 4   54.56  55.04  107.38     0.46     0.06   35.61  914           3
# ..    ...    ...     ...      ...      ...     ...  ...         ...
# 95  14.28  70.13   25.40    16.90    44.19    4.97  327           4
# 96  21.23  17.66   34.42    20.53    85.73   11.56  577           3
# 97   7.56  38.76   38.83     4.92    17.94    1.54  411           3
# 98   7.14  52.07   29.05     5.05    14.00    1.30  212           5
# 99   8.05  36.23   21.58     5.23    15.00    1.02  280           5
#
# [100 rows x 17 columns]

# %%
x1=df2['PM2.5']
y1=df2['CO']

# %%
slope, intercept, r, p, std_err = stats.linregress(x1, y1)

def myfunc(x1):
  return slope * x1 + intercept

# %%
mymodel = list(map(myfunc, x1))
plt.scatter(x1, y1)
plt.plot(x1, mymodel)
plt.show()
